# %%
import pandas as pd
import difflib

# %%
# CSV 파일 경로
file_path = "./data/test_data_edited.csv"

# CSV 파일을 데이터프레임으로 불러오기
df = pd.read_csv(file_path)
df = df.head(500)

# 데이터프레임 확인
df.head()
# Out:
#                                            file_path  \
# 0  ./data/training/REPORT-literature-03965-03965....
# 1  ./data/training/REPORT-literature-02945-02945....
# 2  ./data/training/REPORT-literature-02933-02933....
# 3  ./data/training/REPORT-literature-01925-01925....
# 4  ./data/training/REPORT-literature-02731-02731....
#
#                                                  new  \
# 0   그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈 다. 박...
# 1  ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하면서 돌아왔...
# 2   어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 으면 임종...
# 3   나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하 였다. ...
# 4   한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함은 대단했...
#
#                                                  old  \
# 0        그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈 다.
# 1   ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하면서 돌아왔다.
# 2   어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 으면 임종...
# 3   나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하 였다. ...
# 4   한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함은 대단했...
#
#                                             gptinput  \
# 0  문단1.  그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈...
# 1  문단1.  ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하...
# 2  문단1.  어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 ...
# 3  문단1.  나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하...
# 4  문단1.  한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함...
#
#                                            gptoutput
# 0         박어사가 춘심의 집을 떠나 촉석루로 향하며 사건 준비를 하는 내용이 추가됨.
# 1                     수술 장면과 마취 중 악마와의 환각적인 대화가 추가됨.
# 2     세상에 대한 원망과 자살 시도를 겪고, 결국 구둣방을 시작하게 된 과정이 추가됨..
# 3  직녀가 부모의 강요로 돈을 벌기 위해 타관으로 보내졌으며, 견우와의 비밀 약속이 추가됨.
# 4  병아리 두 마리가 자라 한 쌍이 되었고, 암탉이 첫알을 낳아 가족들이 기뻐한 내용이...

# %%
# 변화를 감지하여 토큰화된 텍스트 생성하는 함수
def detect_changes(old_text, new_text):
    added_parts = []
    for diff in difflib.ndiff(old_text, new_text):
        if diff[0] == '+':
            added_parts.append(diff[2:])
    return old_text + "[ADDED]" + "".join(added_parts) + "[/ADDED]"

# 'text' 열에 변화를 감지한 텍스트 추가
df['text'] = df.apply(lambda row: detect_changes(row['old'], row['new']), axis=1)

# 결과 확인
df
# Out:
#                                             file_path  \
# 0   ./data/training/REPORT-literature-03965-03965....
# 1   ./data/training/REPORT-literature-02945-02945....
# 2   ./data/training/REPORT-literature-02933-02933....
# 3   ./data/training/REPORT-literature-01925-01925....
# 4   ./data/training/REPORT-literature-02731-02731....
# 5   ./data/training/REPORT-literature-01219-01219....
# 6   ./data/training/REPORT-literature-03031-03031....
# 7   ./data/training/REPORT-literature-03267-03267....
# 8   ./data/training/REPORT-literature-01724-01724....
# 9   ./data/training/REPORT-literature-05340-05340....
# 10  ./data/training/REPORT-literature-02375-02375....
# 11  ./data/training/REPORT-literature-03619-03619....
# 12  ./data/training/REPORT-literature-01950-01950....
# 13  ./data/training/REPORT-literature-02894-02894....
# 14  ./data/training/REPORT-literature-05336-05336....
# 15  ./data/training/REPORT-literature-04256-04256....
# 16  ./data/training/REPORT-literature-01453-01453....
# 17  ./data/training/REPORT-literature-01935-01935....
# 18  ./data/training/REPORT-literature-01209-01209....
# 19  ./data/training/REPORT-literature-01737-01737....
# 20  ./data/training/REPORT-literature-04393-04393....
# 21  ./data/training/REPORT-literature-05824-05824....
# 22  ./data/training/REPORT-literature-01798-01798....
# 23  ./data/training/REPORT-literature-04121-04121....
# 24  ./data/training/REPORT-literature-05217-05217....
# 25  ./data/training/REPORT-literature-04742-04742....
# 26  ./data/training/REPORT-literature-04585-04585....
# 27  ./data/training/REPORT-literature-04803-04803....
# 28  ./data/training/REPORT-literature-05405-05405....
# 29  ./data/training/REPORT-literature-02570-02570....
# 30  ./data/training/REPORT-literature-02430-02430....
# 31  ./data/training/REPORT-literature-03904-03904....
# 32  ./data/training/REPORT-literature-02502-02502....
# 33  ./data/training/REPORT-literature-05194-05194....
# 34  ./data/training/REPORT-literature-05723-05723....
# 35  ./data/training/REPORT-literature-01772-01772....
# 36  ./data/training/REPORT-literature-03155-03155....
# 37  ./data/training/REPORT-literature-05858-05858....
# 38  ./data/training/REPORT-literature-03015-03015....
# 39  ./data/training/REPORT-literature-04487-04487....
# 40  ./data/training/REPORT-literature-01700-01700....
# 41  ./data/training/REPORT-literature-05755-05755....
# 42  ./data/training/REPORT-literature-03740-03740....
# 43  ./data/training/REPORT-literature-03890-03890....
# 44  ./data/training/REPORT-literature-05252-05252....
# 45  ./data/training/REPORT-literature-01519-01519....
# 46  ./data/training/REPORT-literature-03063-03063....
# 47  ./data/training/REPORT-literature-03603-03603....
# 48  ./data/training/REPORT-literature-02495-02495....
# 49  ./data/training/REPORT-literature-04207-04207....
#
#                                                   new  \
# 0    그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈 다. 박...
# 1   ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하면서 돌아왔...
# 2    어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 으면 임종...
# 3    나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하 였다. ...
# 4    한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함은 대단했...
# 5   그리운 흘긴 눈 그이와 살림을 하기는, 내가 열 아홉 살 먹던 봄이었습니다. 시방은...
# 6    “다시 살아서 여행을 떠난다, 거짓말이다 거짓말이다.” 하면서 나는 그들을 따랐다...
# 7   바다에까지 나가기도 귀찮아 풀포기에 쓰러진 채 밤을 새웠다. 다음날도 집에 들어가지...
# 8    연숙은 의장에 머리를 기대고 마침내 소리를 내어 운다. 오늘의 이 불행의 원인이 ...
# 9    “글 잘 읽었느냐?” “네에!” “………” 박씨부 인은 말없이 고개만 가볍게 끄덕...
# 10  죽기가 아까운 바는 아니다. 그러나 자기 한 사람이 없어진다 하는 것은 신라의 국가...
# 11   “어떡하랍시요” 급사는 열적은 듯이 혼자 머리를 굽실하면서 또다시 물었다. “간다...
# 12  명수는 얄미운 생각이 났다. “자네가 그렇게 유랑 생활할 생각을 진즉에 하였다면 자...
# 13   “그러기에 등하불명이랍니다. 좌우간 댁부터 수색을 해 보아야 돼요. 어 때요, 명...
# 14  경제생활과 신앙 김교신 나의 오늘날까지의 생애에서 만나 본 사람 중에 가장 간교하고...
# 15  “얼마나 쓰시려우?” “오,십,전,만.” 여인은, 말을 채 마치지를 못하였습니다. ...
# 16   경도의 뇌산양이 그리웠다. 연전 서로 만났을 때는 단지 한 개 학자로 서 로 즐겁...
# 17   "그러니까 남녀 평등이란 말 뿐이지, 좀처럼 실현되기는 힘들 꺼예요. 될 수만 있...
# 18  “영애는 그 자리가 좋아서 가나요?” 채영은 영애의 마음을 이 노파를 통해 들어보고...
# 19  “일어나！” 하는 소리는 누가 멀리서 들리는 것 같다. 사슈가는 어안이 벙벙하였다가...
# 20   "앞으로 십 오년만 더 살고 죽으면 저것들이 다 성취하는 것을 보겠지." 김씨 부...
# 21   이것은 그 여인의 뒤에서 짐을 싣고 오다가 목도(目睹)했다는 우차부(牛 車夫)의 ...
# 22   "그렇지만 영훈씨를 늘상 생각하면서 살았으니까, 별반 불행한 삶은 아니 었어요."...
# 23   “두구 보세요 다음 기회는 영락없을 테니. 사람의 운이 한 번은 이로울 날 있겠지...
# 24  어린이는 그림을 좋아한다. 그리고, 또 그리기를 좋아한다. 조금도 기교가 없는 순진...
# 25  뒤이어 청록파의 지론자인 조지훈은 <예정조화>라는 말을 씀으로써 앞의 인용한 편석촌...
# 26  4. 극문학 만근(輓近) 각 사립 남녀전문학교를 중심으로 일어나는 신극운동은 실로 ...
# 27  자랑 가만 보면 자랑하려는 마음처럼 무서운 마음은 없는 것 같다. 자기를 자랑하려고...
# 28   그러나 소설이라 하는 것이 문장예술인 이상 마치 회화의 색채와 같은 정 도의 중요...
# 29  SS는 보산을 향하여 예언자와같은 엄숙한 얼굴을 하더니 떡큼직하게하품을 한번하고 나...
# 30   "배라먹 을 녀석! 버르쟁이를 가르쳐야……." 빽 쏘는 소리가 도리어 늦다 할이 ...
# 31   “이놈 버릇 없이……. 흐흥.” 허준이도 담배를 받으면서 점잔을 빼다 말고 웃었다...
# 32   어느 때인가 상철은 무서운 꿈에서 깨었다. 방안은 캄캄하다. 그것은 자기 가 도둑...
# 33  〈노라〉 서 우리 문단의 과거를 회고하여 보라. 우리의 문예는 과거에 우리 생활에 ...
# 34   어머님은 매우 건강한 체질의 소유자였다. 어머님이 제일차의 뇌일혈로 넘어지신 것은...
# 35   낙랑의 북과 나발이 없어진 덕에 고구려는 손쉽게 낙랑을 정복하였다. 말하자면 이번...
# 36  이리하여 수 일이 지났다. 그러는 동안에 이상한 일을 당하였다. 인준에게서 1, 김...
# 37  꿈많은 처녀시절 봄은 되었건만 일기는 불순하고 연일 바람이 거세다. 불원(不遠)하여...
# 38  북국점경(北國點景) 능 금(林檎) 능금나무 동산 아름다운 옛 동산, 지금에는 찾을 ...
# 39  사실 나는 근 20년 경성을, 주로 객지의 하숙생활을 하였고, 그러노라 니 늘 겨울...
# 40   "어리기는 열 다섯 살이 어려요?" 평목의 눈이 빛났다. 조신은 한 번 더 동이덩...
# 41  음악야화(音樂夜話) 이탈리아 소녀 산뜻한 옷을 맵시 나게 입은 파리의 젊은이들은 가...
# 42   “벌써 반회갑이 아니냐. 너도 내 나이이 돼 봐라.” 나를 쳐다보는 그의 커다란 ...
# 43   “그럼 와 그러는 게유? 우리집 이 굶을까 봐 그리시유?” “…….” “어머이도 ...
# 44  또 어느날 몬텔뀨는 루이스를 방문하니까 수염이 거친 낯선 남자 하나가 셔츠만 입고서...
# 45   × 고금동서에 다시 보기 힘든 명군 세종대왕은, 이러한 불상사를 보신 뒤에 등극을...
# 46  무엇보다 어린 바위가 눈물겹게 불쌍하게 생각이 들었다. 선주는 장사의 눈치를 살피며...
# 47   대처(都市)가 그러한 데 비하여 고향은 차라리 안전하였다. 우선 당장은 각다분하겠...
# 48  남산 밑 풀과 나무에 빛나던 붉은 빛은 점점 걷히고 모색(暮色)이 이물이 물 쳐들어...
# 49   원선 이는 숙희 앉은 편으로 뛰어갔다. 서로 손을 잡고 이편으로 뛰어오자, “어서...
#
#                                                   old  \
# 0         그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈 다.
# 1    ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하면서 돌아왔다.
# 2    어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 으면 임종...
# 3    나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하 였다. ...
# 4    한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함은 대단했...
# 5   그리운 흘긴 눈 그이와 살림을 하기는, 내가 열 아홉 살 먹던 봄이었습니다. 시방은...
# 6      “다시 살아서 여행을 떠난다, 거짓말이다 거짓말이다.” 하면서 나는 그들을 따랐다.
# 7   바다에까지 나가기도 귀찮아 풀포기에 쓰러진 채 밤을 새웠다. 다음날도 집에 들어가지...
# 8    연숙은 의장에 머리를 기대고 마침내 소리를 내어 운다. 오늘의 이 불행의 원인이 ...
# 9    “글 잘 읽었느냐?” “네에!” “………” 박씨부 인은 말없이 고개만 가볍게 끄덕...
# 10  죽기가 아까운 바는 아니다. 그러나 자기 한 사람이 없어진다 하는 것은 신라의 국가...
# 11   “어떡하랍시요” 급사는 열적은 듯이 혼자 머리를 굽실하면서 또다시 물었다. “간다...
# 12  명수는 얄미운 생각이 났다. “자네가 그렇게 유랑 생활할 생각을 진즉에 하였다면 자...
# 13   “그러기에 등하불명이랍니다. 좌우간 댁부터 수색을 해 보아야 돼요. 어 때요, 명...
# 14  경제생활과 신앙 김교신 나의 오늘날까지의 생애에서 만나 본 사람 중에 가장 간교하고...
# 15                             “얼마나 쓰시려우?” “오,십,전,만.”
# 16   경도의 뇌산양이 그리웠다. 연전 서로 만났을 때는 단지 한 개 학자로 서 로 즐겁...
# 17   "그러니까 남녀 평등이란 말 뿐이지, 좀처럼 실현되기는 힘들 꺼예요. 될 수만 있...
# 18  “영애는 그 자리가 좋아서 가나요?” 채영은 영애의 마음을 이 노파를 통해 들어보고...
# 19  “일어나！” 하는 소리는 누가 멀리서 들리는 것 같다. 사슈가는 어안이 벙벙하였다가...
# 20   "앞으로 십 오년만 더 살고 죽으면 저것들이 다 성취하는 것을 보겠지." 김씨 부...
# 21   이것은 그 여인의 뒤에서 짐을 싣고 오다가 목도(目睹)했다는 우차부(牛 車夫)의 ...
# 22   "그렇지만 영훈씨를 늘상 생각하면서 살았으니까, 별반 불행한 삶은 아니 었어요."...
# 23   “두구 보세요 다음 기회는 영락없을 테니. 사람의 운이 한 번은 이로울 날 있겠지요.”
# 24                   어린이는 그림을 좋아한다. 그리고, 또 그리기를 좋아한다.
# 25   뒤이어 청록파의 지론자인 조지훈은 <예정조화>라는 말을 씀으로써 앞의 인용한 편석...
# 26  4. 극문학 만근(輓近) 각 사립 남녀전문학교를 중심으로 일어나는 신극운동은 실로 ...
# 27  자랑 가만 보면 자랑하려는 마음처럼 무서운 마음은 없는 것 같다. 자기를 자랑하려고...
# 28   그러나 소설이라 하는 것이 문장예술인 이상 마치 회화의 색채와 같은 정 도의 중요...
# 29  SS는 보산을 향하여 예언자와같은 엄숙한 얼굴을 하더니 떡큼직하게하품을 한번하고 나...
# 30   "배라먹 을 녀석! 버르쟁이를 가르쳐야……." 빽 쏘는 소리가 도리어 늦다 할이 ...
# 31                                  “이놈 버릇 없이……. 흐흥.”
# 32                  어느 때인가 상철은 무서운 꿈에서 깨었다. 방안은 캄캄하다.
# 33  〈노라〉 서 우리 문단의 과거를 회고하여 보라. 우리의 문예는 과거에 우리 생활에 ...
# 34   어머님은 매우 건강한 체질의 소유자였다. 어머님이 제일차의 뇌일혈로 넘어지신 것은...
# 35   낙랑의 북과 나발이 없어진 덕에 고구려는 손쉽게 낙랑을 정복하였다. 말하자면 이번...
# 36                이리하여 수 일이 지났다. 그러는 동안에 이상한 일을 당하였다.
# 37  꿈많은 처녀시절 봄은 되었건만 일기는 불순하고 연일 바람이 거세다. 불원(不遠)하여...
# 38  북국점경(北國點景) 능 금(林檎) 능금나무 동산 아름다운 옛 동산, 지금에는 찾을 ...
# 39  사실 나는 근 20년 경성을, 주로 객지의 하숙생활을 하였고, 그러노라 니 늘 겨울...
# 40                    "어리기는 열 다섯 살이 어려요?" 평목의 눈이 빛났다.
# 41  음악야화(音樂夜話) 이탈리아 소녀 산뜻한 옷을 맵시 나게 입은 파리의 젊은이들은 가...
# 42                      “벌써 반회갑이 아니냐. 너도 내 나이이 돼 봐라.”
# 43                   “그럼 와 그러는 게유? 우리집 이 굶을까 봐 그리시유?”
# 44   또 어느날 몬텔뀨는 루이스를 방문하니까 수염이 거친 낯선 남자 하나가 셔츠만 입고...
# 45   × 고금동서에 다시 보기 힘든 명군 세종대왕은, 이러한 불상사를 보신 뒤에 등극을...
# 46  무엇보다 어린 바위가 눈물겹게 불쌍하게 생각이 들었다. 선주는 장사의 눈치를 살피며...
# 47   대처(都市)가 그러한 데 비하여 고향은 차라리 안전하였다. 우선 당장은 각다분하겠...
# 48   남산 밑 풀과 나무에 빛나던 붉은 빛은 점점 걷히고 모색(暮色)이 이물이 물 쳐들...
# 49   원선 이는 숙희 앉은 편으로 뛰어갔다. 서로 손을 잡고 이편으로 뛰어오자, “어서...
#
#                                              gptinput  \
# 0   문단1.  그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈...
# 1   문단1.  ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하...
# 2   문단1.  어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 ...
# 3   문단1.  나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하...
# 4   문단1.  한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함...
# 5   문단1. 그리운 흘긴 눈 그이와 살림을 하기는, 내가 열 아홉 살 먹던 봄이었습니다...
# 6   문단1.  “다시 살아서 여행을 떠난다, 거짓말이다 거짓말이다.” 하면서 나는 그들...
# 7   문단1. 바다에까지 나가기도 귀찮아 풀포기에 쓰러진 채 밤을 새웠다. 다음날도 집에...
# 8   문단1.  연숙은 의장에 머리를 기대고 마침내 소리를 내어 운다. 오늘의 이 불행의...
# 9   문단1.  “글 잘 읽었느냐?” “네에!” “………” 박씨부 인은 말없이 고개만 가...
# 10  문단1. 죽기가 아까운 바는 아니다. 그러나 자기 한 사람이 없어진다 하는 것은 신...
# 11  문단1.  “어떡하랍시요” 급사는 열적은 듯이 혼자 머리를 굽실하면서 또다시 물었다...
# 12  문단1. 명수는 얄미운 생각이 났다. “자네가 그렇게 유랑 생활할 생각을 진즉에 하...
# 13  문단1.  “그러기에 등하불명이랍니다. 좌우간 댁부터 수색을 해 보아야 돼요. 어 ...
# 14  문단1. 경제생활과 신앙 김교신 나의 오늘날까지의 생애에서 만나 본 사람 중에 가장...
# 15  문단1.  “얼마나 쓰시려우?” “오,십,전,만.”\n\n문단2.  “얼마나 쓰시려...
# 16  문단1.  경도의 뇌산양이 그리웠다. 연전 서로 만났을 때는 단지 한 개 학자로 서...
# 17  문단1.  "그러니까 남녀 평등이란 말 뿐이지, 좀처럼 실현되기는 힘들 꺼예요. 될...
# 18  문단1. “영애는 그 자리가 좋아서 가나요?” 채영은 영애의 마음을 이 노파를 통해...
# 19  문단1. “일어나！” 하는 소리는 누가 멀리서 들리는 것 같다. 사슈가는 어안이 벙...
# 20  문단1.  "앞으로 십 오년만 더 살고 죽으면 저것들이 다 성취하는 것을 보겠지."...
# 21  문단1.  이것은 그 여인의 뒤에서 짐을 싣고 오다가 목도(目睹)했다는 우차부(牛 ...
# 22  문단1.  "그렇지만 영훈씨를 늘상 생각하면서 살았으니까, 별반 불행한 삶은 아니 ...
# 23  문단1.  “두구 보세요 다음 기회는 영락없을 테니. 사람의 운이 한 번은 이로울 ...
# 24  문단1.  어린이는 그림을 좋아한다. 그리고, 또 그리기를 좋아한다.\n\n문단2....
# 25  문단1.  뒤이어 청록파의 지론자인 조지훈은 <예정조화>라는 말을 씀으로써 앞의 인...
# 26  문단1. 4. 극문학 만근(輓近) 각 사립 남녀전문학교를 중심으로 일어나는 신극운동...
# 27  문단1. 자랑 가만 보면 자랑하려는 마음처럼 무서운 마음은 없는 것 같다. 자기를 ...
# 28  문단1.  그러나 소설이라 하는 것이 문장예술인 이상 마치 회화의 색채와 같은 정 ...
# 29  문단1. SS는 보산을 향하여 예언자와같은 엄숙한 얼굴을 하더니 떡큼직하게하품을 한...
# 30  문단1.  "배라먹 을 녀석! 버르쟁이를 가르쳐야……." 빽 쏘는 소리가 도리어 늦...
# 31  문단1.  “이놈 버릇 없이……. 흐흥.”\n\n문단2.  “이놈 버릇 없이……. ...
# 32  문단1.  어느 때인가 상철은 무서운 꿈에서 깨었다. 방안은 캄캄하다.\n\n문단2...
# 33  문단1. 〈노라〉 서 우리 문단의 과거를 회고하여 보라. 우리의 문예는 과거에 우리...
# 34  문단1.  어머님은 매우 건강한 체질의 소유자였다. 어머님이 제일차의 뇌일혈로 넘어...
# 35  문단1.  낙랑의 북과 나발이 없어진 덕에 고구려는 손쉽게 낙랑을 정복하였다. 말하...
# 36  문단1. 이리하여 수 일이 지났다. 그러는 동안에 이상한 일을 당하였다.\n\n문단...
# 37  문단1. 꿈많은 처녀시절 봄은 되었건만 일기는 불순하고 연일 바람이 거세다. 불원(...
# 38  문단1. 북국점경(北國點景) 능 금(林檎) 능금나무 동산 아름다운 옛 동산, 지금에...
# 39  문단1.  사실 나는 근 20년 경성을, 주로 객지의 하숙생활을 하였고, 그러노라 ...
# 40  문단1.  "어리기는 열 다섯 살이 어려요?" 평목의 눈이 빛났다.\n\n문단2. ...
# 41  문단1. 음악야화(音樂夜話) 이탈리아 소녀 산뜻한 옷을 맵시 나게 입은 파리의 젊은...
# 42  문단1.  “벌써 반회갑이 아니냐. 너도 내 나이이 돼 봐라.”\n\n문단2.  “...
# 43  문단1.  “그럼 와 그러는 게유? 우리집 이 굶을까 봐 그리시유?”\n\n문단2....
# 44  문단1.  또 어느날 몬텔뀨는 루이스를 방문하니까 수염이 거친 낯선 남자 하나가 셔...
# 45  문단1.  × 고금동서에 다시 보기 힘든 명군 세종대왕은, 이러한 불상사를 보신 뒤...
# 46  문단1. 무엇보다 어린 바위가 눈물겹게 불쌍하게 생각이 들었다. 선주는 장사의 눈치...
# 47  문단1.  대처(都市)가 그러한 데 비하여 고향은 차라리 안전하였다. 우선 당장은 ...
# 48  문단1.  남산 밑 풀과 나무에 빛나던 붉은 빛은 점점 걷히고 모색(暮色)이 이물이...
# 49  문단1.  원선 이는 숙희 앉은 편으로 뛰어갔다. 서로 손을 잡고 이편으로 뛰어오자...
#
#                                             gptoutput  \
# 0          박어사가 춘심의 집을 떠나 촉석루로 향하며 사건 준비를 하는 내용이 추가됨.
# 1                      수술 장면과 마취 중 악마와의 환각적인 대화가 추가됨.
# 2      세상에 대한 원망과 자살 시도를 겪고, 결국 구둣방을 시작하게 된 과정이 추가됨..
# 3   직녀가 부모의 강요로 돈을 벌기 위해 타관으로 보내졌으며, 견우와의 비밀 약속이 추가됨.
# 4   병아리 두 마리가 자라 한 쌍이 되었고, 암탉이 첫알을 낳아 가족들이 기뻐한 내용이...
# 5   기생으로서의 젊은 시절을 회상하며 당시의 외모와 생활의 고달픔을 묘사하는 내용이 추가됨.
# 6       R과 S와 작별 후 어머니와 함께하며, 생명과 의사의 역할에 대한 생각이 추가됨.
# 7    분녀는 집으로 끌려가며 큰일이 치러진 것으로 느꼈고, 이후 삶이 변화된 내용이 추가됨.
# 8   연숙은 김석호에게서 아내로써 자유를 얻는다는 약속을 받고, 불안한 상황에 우는 내용...
# 9     준호는 둘째 즐거움이 끝날 것을 알면서도 비로소 안도의 빛이 떠오르는 내용이 추가됨.
# 10  국가적 안목으로 보아 죽는 것은 의미 없고, 곧바로 귀국하여 공로를 세우는 것이 중...
# 11  춘수가 급사에게 놀란 채로 거침없는 말을 내뱉으며 잡지를 버리라고 권유하는 내용이 ...
# 12               명수와 석호가 석호의 아편 중독에 관해 이야기하는 내용이 추가됨.
# 13   애라가 수색을 지시하고, 형사과장이 증거를 찾지만 아무것도 찾지 못하는 내용이 추가됨.
# 14                 신앙에 따른 경제생활의 차이와 경외하는 선배의 사례가 추가됨.
# 15      여인이 애 아버지의 일 사정을 설명하며 삼덕이에게 약값을 구걸하는 장면이 추가됨.
# 16   성암이 뇌산양의 사상을 음미하고, 자신의 시 창작 방법의 변화를 깨달은 내용이 추가됨.
# 17     은주가 여성이 남성의 속내를 이해하고 이를 활용하는 특징을 설명하는 내용이 추가됨.
# 18           채영이 영애의 결혼 상대를 이해하기 위해 노파와 상담하는 내용이 추가됨.
# 19  사슈가 일어나며 피가 흘러난다는 것을 알지만, 몸은 약해진 채로 피투성이 손으로 금...
# 20  김씨 부인이 감기로 앓다가 폐암 판정을 받고 죽기 직전까지 순수하고 착한 모습을 보...
# 21             남편을 잊지 못한 부인의 대담한 재혼 결심과 그 후의 행동이 추가됨.
# 22           영훈의 아내, 백연숙이 어떤 불행한 결혼 생활을 털어놓는 내용이 추가됨.
# 23          아내가 집에 도착해 만발한 꽃들과 새 집을 즐기며 기뻐하는 내용이 추가됨.
# 24              어린이의 순진한 예술 표현과 그 예술적 가치에 대한 찬미가 추가됨.
# 25          조지훈의 시적 변화와 새로운 언어 감각의 어려움을 설명하는 내용이 추가됨.
# 26  학생들의 진지한 신극운동의 장래성과 극본 기근 및 지도자의 필요성에 대한 내용이 추가됨.
# 27     사람의 모든 행동과 성격이 자기를 높이려는 자랑의 마음에서 나온다는 내용이 추가됨.
# 28      에드가 앨런 포와 체홉의 작품에서 문장과 내용의 조화가 중요하다는 예시가 추가됨.
# 29  SS와 보산 사이의 대화와 갈등이 더 구체적으로 전개되고, 보산이 SS를 총살할 계...
# 30  사내가 대야에 맞고 도망친 후, 당혹감과 분노를 느끼며 길가에서 혼란스러워하는 내용...
# 31  허준이가 친구의 호의를 거절하며 밥을 먹으러 가는 길에 망설이고 혼란스러워하는 내용...
# 32            상철이 굶주림과 생명의 위기를 느끼며 도둑질을 고민하는 내용이 추가됨.
# 33    우리 문단이 세계사조와 신문예 운동의 영향으로 새롭게 변화하고 있다는 내용이 추가됨.
# 34        어머니가 두 번의 뇌일혈을 겪고 회복 중이지만, 매우 약해진 상태임이 추가됨.
# 35  공주의 배신과 죽음으로 인해 고구려가 낙랑을 쉽게 정복했지만, 왕자는 공주의 죽음을...
# 36  서인준이 필호에게 김소춘 문제와 상해로 돌아가는 것을 눈감아 달라고 요구하며, 이에...
# 37  꿈많은 처녀가 친구 순희에게 결혼과 진로에 대해 신중히 고민하라고 조언하며 상경을 ...
# 38  능금밭의 옛 추억과 아름다운 풍경이 세월이 흐르며 사라지고 변한 것에 대한 묘사가 ...
# 39  병이 자주 재발하며 특히 춘하간과 추동간에 심해져 이번에는 기록적으로 오래 앓았음을...
# 40  조신은 평목을 죽이기로 결심하지만, 평목을 살려두면 딸과 재물을 요구할까 두려워하는...
# 41   카페에서 노래하는 이탈리아 소녀의 신비한 배경과 그녀를 쫓는 사람들의 이야기가 추가됨.
# 42  배옥이를 만나고 싶은 마음에 진남포로 갔으나, 정월 흥행 중에도 그를 만나지 못한 ...
# 43       남자가 젊은 아낙에게 결혼을 제안하여 대례를 치르고 잔치를 벌인 내용이 추가됨.
# 44                 루이스가 남을 배려하는 성품과 루카스를 용서한 사건이 추가됨.
# 45  양녕이 광주에서 소인배들의 참소를 염려하며 지내다 세종의 초대로 동교로 가는 내용이...
# 46       선주가 장사를 내쫓으려 하고, 장사는 낚시하며 고통스럽게 지내는 내용이 추가됨.
# 47             민족해방 후에도 여전히 약하고 용렬한 자신을 자각하는 내용이 추가됨.
# 48       누님과 K씨의 대화와 누님의 눈물, 어머니와 누님의 밤중 대화와 울음이 추가됨.
# 49     원선 이와 친구들의 작별, 옥이의 일상, 영실 어머니의 등장과 편지 전달이 추가됨.
#
#                                                  text
# 0    그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈 다.[A...
# 1    ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하면서 돌아...
# 2    어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 으면 임종...
# 3    나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하 였다. ...
# 4    한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함은 대단했...
# 5   그리운 흘긴 눈 그이와 살림을 하기는, 내가 열 아홉 살 먹던 봄이었습니다. 시방은...
# 6    “다시 살아서 여행을 떠난다, 거짓말이다 거짓말이다.” 하면서 나는 그들을 따랐다...
# 7   바다에까지 나가기도 귀찮아 풀포기에 쓰러진 채 밤을 새웠다. 다음날도 집에 들어가지...
# 8    연숙은 의장에 머리를 기대고 마침내 소리를 내어 운다. 오늘의 이 불행의 원인이 ...
# 9    “글 잘 읽었느냐?” “네에!” “………” 박씨부 인은 말없이 고개만 가볍게 끄덕...
# 10  죽기가 아까운 바는 아니다. 그러나 자기 한 사람이 없어진다 하는 것은 신라의 국가...
# 11   “어떡하랍시요” 급사는 열적은 듯이 혼자 머리를 굽실하면서 또다시 물었다. “간다...
# 12  명수는 얄미운 생각이 났다. “자네가 그렇게 유랑 생활할 생각을 진즉에 하였다면 자...
# 13   “그러기에 등하불명이랍니다. 좌우간 댁부터 수색을 해 보아야 돼요. 어 때요, 명...
# 14  경제생활과 신앙 김교신 나의 오늘날까지의 생애에서 만나 본 사람 중에 가장 간교하고...
# 15   “얼마나 쓰시려우?” “오,십,전,만.”[ADDED] 여인은, 말을 채 마치지를 ...
# 16   경도의 뇌산양이 그리웠다. 연전 서로 만났을 때는 단지 한 개 학자로 서 로 즐겁...
# 17   "그러니까 남녀 평등이란 말 뿐이지, 좀처럼 실현되기는 힘들 꺼예요. 될 수만 있...
# 18  “영애는 그 자리가 좋아서 가나요?” 채영은 영애의 마음을 이 노파를 통해 들어보고...
# 19  “일어나！” 하는 소리는 누가 멀리서 들리는 것 같다. 사슈가는 어안이 벙벙하였다가...
# 20   "앞으로 십 오년만 더 살고 죽으면 저것들이 다 성취하는 것을 보겠지." 김씨 부...
# 21   이것은 그 여인의 뒤에서 짐을 싣고 오다가 목도(目睹)했다는 우차부(牛 車夫)의 ...
# 22   "그렇지만 영훈씨를 늘상 생각하면서 살았으니까, 별반 불행한 삶은 아니 었어요."...
# 23   “두구 보세요 다음 기회는 영락없을 테니. 사람의 운이 한 번은 이로울 날 있겠지...
# 24   어린이는 그림을 좋아한다. 그리고, 또 그리기를 좋아한다.[ADDED] 조금도 기...
# 25   뒤이어 청록파의 지론자인 조지훈은 <예정조화>라는 말을 씀으로써 앞의 인용한 편석...
# 26  4. 극문학 만근(輓近) 각 사립 남녀전문학교를 중심으로 일어나는 신극운동은 실로 ...
# 27  자랑 가만 보면 자랑하려는 마음처럼 무서운 마음은 없는 것 같다. 자기를 자랑하려고...
# 28   그러나 소설이라 하는 것이 문장예술인 이상 마치 회화의 색채와 같은 정 도의 중요...
# 29  SS는 보산을 향하여 예언자와같은 엄숙한 얼굴을 하더니 떡큼직하게하품을 한번하고 나...
# 30   "배라먹 을 녀석! 버르쟁이를 가르쳐야……." 빽 쏘는 소리가 도리어 늦다 할이 ...
# 31   “이놈 버릇 없이……. 흐흥.”[ADDED] 허준이도 담배를 받으면서 점잔을 빼다...
# 32   어느 때인가 상철은 무서운 꿈에서 깨었다. 방안은 캄캄하다.[ADDED] 그것은 ...
# 33  〈노라〉 서 우리 문단의 과거를 회고하여 보라. 우리의 문예는 과거에 우리 생활에 ...
# 34   어머님은 매우 건강한 체질의 소유자였다. 어머님이 제일차의 뇌일혈로 넘어지신 것은...
# 35   낙랑의 북과 나발이 없어진 덕에 고구려는 손쉽게 낙랑을 정복하였다. 말하자면 이번...
# 36  이리하여 수 일이 지났다. 그러는 동안에 이상한 일을 당하였다.[ADDED] 인준에...
# 37  꿈많은 처녀시절 봄은 되었건만 일기는 불순하고 연일 바람이 거세다. 불원(不遠)하여...
# 38  북국점경(北國點景) 능 금(林檎) 능금나무 동산 아름다운 옛 동산, 지금에는 찾을 ...
# 39  사실 나는 근 20년 경성을, 주로 객지의 하숙생활을 하였고, 그러노라 니 늘 겨울...
# 40   "어리기는 열 다섯 살이 어려요?" 평목의 눈이 빛났다.[ADDED] 조신은 한 ...
# 41  음악야화(音樂夜話) 이탈리아 소녀 산뜻한 옷을 맵시 나게 입은 파리의 젊은이들은 가...
# 42   “벌써 반회갑이 아니냐. 너도 내 나이이 돼 봐라.”[ADDED] 나를 쳐다보는 ...
# 43   “그럼 와 그러는 게유? 우리집 이 굶을까 봐 그리시유?”[ADDED] “…….”...
# 44   또 어느날 몬텔뀨는 루이스를 방문하니까 수염이 거친 낯선 남자 하나가 셔츠만 입고...
# 45   × 고금동서에 다시 보기 힘든 명군 세종대왕은, 이러한 불상사를 보신 뒤에 등극을...
# 46  무엇보다 어린 바위가 눈물겹게 불쌍하게 생각이 들었다. 선주는 장사의 눈치를 살피며...
# 47   대처(都市)가 그러한 데 비하여 고향은 차라리 안전하였다. 우선 당장은 각다분하겠...
# 48   남산 밑 풀과 나무에 빛나던 붉은 빛은 점점 걷히고 모색(暮色)이 이물이 물 쳐들...
# 49   원선 이는 숙희 앉은 편으로 뛰어갔다. 서로 손을 잡고 이편으로 뛰어오자, “어서...

# %%
# 'file_path', 'new', 'old', 'gptinput' 열 삭제
df.drop(columns=['file_path', 'new', 'old', 'gptinput'], inplace=True)

# 'gptoutput' 열 이름을 'summary'로 변경
df.rename(columns={'gptoutput': 'summary'}, inplace=True)

df
# Out:
#                                               summary  \
# 0          박어사가 춘심의 집을 떠나 촉석루로 향하며 사건 준비를 하는 내용이 추가됨.
# 1                      수술 장면과 마취 중 악마와의 환각적인 대화가 추가됨.
# 2      세상에 대한 원망과 자살 시도를 겪고, 결국 구둣방을 시작하게 된 과정이 추가됨..
# 3   직녀가 부모의 강요로 돈을 벌기 위해 타관으로 보내졌으며, 견우와의 비밀 약속이 추가됨.
# 4   병아리 두 마리가 자라 한 쌍이 되었고, 암탉이 첫알을 낳아 가족들이 기뻐한 내용이...
# 5   기생으로서의 젊은 시절을 회상하며 당시의 외모와 생활의 고달픔을 묘사하는 내용이 추가됨.
# 6       R과 S와 작별 후 어머니와 함께하며, 생명과 의사의 역할에 대한 생각이 추가됨.
# 7    분녀는 집으로 끌려가며 큰일이 치러진 것으로 느꼈고, 이후 삶이 변화된 내용이 추가됨.
# 8   연숙은 김석호에게서 아내로써 자유를 얻는다는 약속을 받고, 불안한 상황에 우는 내용...
# 9     준호는 둘째 즐거움이 끝날 것을 알면서도 비로소 안도의 빛이 떠오르는 내용이 추가됨.
# 10  국가적 안목으로 보아 죽는 것은 의미 없고, 곧바로 귀국하여 공로를 세우는 것이 중...
# 11  춘수가 급사에게 놀란 채로 거침없는 말을 내뱉으며 잡지를 버리라고 권유하는 내용이 ...
# 12               명수와 석호가 석호의 아편 중독에 관해 이야기하는 내용이 추가됨.
# 13   애라가 수색을 지시하고, 형사과장이 증거를 찾지만 아무것도 찾지 못하는 내용이 추가됨.
# 14                 신앙에 따른 경제생활의 차이와 경외하는 선배의 사례가 추가됨.
# 15      여인이 애 아버지의 일 사정을 설명하며 삼덕이에게 약값을 구걸하는 장면이 추가됨.
# 16   성암이 뇌산양의 사상을 음미하고, 자신의 시 창작 방법의 변화를 깨달은 내용이 추가됨.
# 17     은주가 여성이 남성의 속내를 이해하고 이를 활용하는 특징을 설명하는 내용이 추가됨.
# 18           채영이 영애의 결혼 상대를 이해하기 위해 노파와 상담하는 내용이 추가됨.
# 19  사슈가 일어나며 피가 흘러난다는 것을 알지만, 몸은 약해진 채로 피투성이 손으로 금...
# 20  김씨 부인이 감기로 앓다가 폐암 판정을 받고 죽기 직전까지 순수하고 착한 모습을 보...
# 21             남편을 잊지 못한 부인의 대담한 재혼 결심과 그 후의 행동이 추가됨.
# 22           영훈의 아내, 백연숙이 어떤 불행한 결혼 생활을 털어놓는 내용이 추가됨.
# 23          아내가 집에 도착해 만발한 꽃들과 새 집을 즐기며 기뻐하는 내용이 추가됨.
# 24              어린이의 순진한 예술 표현과 그 예술적 가치에 대한 찬미가 추가됨.
# 25          조지훈의 시적 변화와 새로운 언어 감각의 어려움을 설명하는 내용이 추가됨.
# 26  학생들의 진지한 신극운동의 장래성과 극본 기근 및 지도자의 필요성에 대한 내용이 추가됨.
# 27     사람의 모든 행동과 성격이 자기를 높이려는 자랑의 마음에서 나온다는 내용이 추가됨.
# 28      에드가 앨런 포와 체홉의 작품에서 문장과 내용의 조화가 중요하다는 예시가 추가됨.
# 29  SS와 보산 사이의 대화와 갈등이 더 구체적으로 전개되고, 보산이 SS를 총살할 계...
# 30  사내가 대야에 맞고 도망친 후, 당혹감과 분노를 느끼며 길가에서 혼란스러워하는 내용...
# 31  허준이가 친구의 호의를 거절하며 밥을 먹으러 가는 길에 망설이고 혼란스러워하는 내용...
# 32            상철이 굶주림과 생명의 위기를 느끼며 도둑질을 고민하는 내용이 추가됨.
# 33    우리 문단이 세계사조와 신문예 운동의 영향으로 새롭게 변화하고 있다는 내용이 추가됨.
# 34        어머니가 두 번의 뇌일혈을 겪고 회복 중이지만, 매우 약해진 상태임이 추가됨.
# 35  공주의 배신과 죽음으로 인해 고구려가 낙랑을 쉽게 정복했지만, 왕자는 공주의 죽음을...
# 36  서인준이 필호에게 김소춘 문제와 상해로 돌아가는 것을 눈감아 달라고 요구하며, 이에...
# 37  꿈많은 처녀가 친구 순희에게 결혼과 진로에 대해 신중히 고민하라고 조언하며 상경을 ...
# 38  능금밭의 옛 추억과 아름다운 풍경이 세월이 흐르며 사라지고 변한 것에 대한 묘사가 ...
# 39  병이 자주 재발하며 특히 춘하간과 추동간에 심해져 이번에는 기록적으로 오래 앓았음을...
# 40  조신은 평목을 죽이기로 결심하지만, 평목을 살려두면 딸과 재물을 요구할까 두려워하는...
# 41   카페에서 노래하는 이탈리아 소녀의 신비한 배경과 그녀를 쫓는 사람들의 이야기가 추가됨.
# 42  배옥이를 만나고 싶은 마음에 진남포로 갔으나, 정월 흥행 중에도 그를 만나지 못한 ...
# 43       남자가 젊은 아낙에게 결혼을 제안하여 대례를 치르고 잔치를 벌인 내용이 추가됨.
# 44                 루이스가 남을 배려하는 성품과 루카스를 용서한 사건이 추가됨.
# 45  양녕이 광주에서 소인배들의 참소를 염려하며 지내다 세종의 초대로 동교로 가는 내용이...
# 46       선주가 장사를 내쫓으려 하고, 장사는 낚시하며 고통스럽게 지내는 내용이 추가됨.
# 47             민족해방 후에도 여전히 약하고 용렬한 자신을 자각하는 내용이 추가됨.
# 48       누님과 K씨의 대화와 누님의 눈물, 어머니와 누님의 밤중 대화와 울음이 추가됨.
# 49     원선 이와 친구들의 작별, 옥이의 일상, 영실 어머니의 등장과 편지 전달이 추가됨.
#
#                                                  text
# 0    그밤 은 온갖 축복(祝福)과 감사 속에서 밝았다. 춘심은 조반상을 물러냈 다.[A...
# 1    ‘몇 시간 걸리는가.’ R은 맞은편에 있던 나의 마음은, 이런 생각을 하면서 돌아...
# 2    어머니께서는 나 때문에 돌아가셨읍니다. 이 불효 자식이 여북 보고 싶었 으면 임종...
# 3    나이 어린 딸을 둔 가난한 집안에서 너도 나도 하고 열다섯 명이나 응모하 였다. ...
# 4    한 마리 한 마리 없어질 적마다 태진이와 또 용동댁이며 그 모친의 섭섭함은 대단했...
# 5   그리운 흘긴 눈 그이와 살림을 하기는, 내가 열 아홉 살 먹던 봄이었습니다. 시방은...
# 6    “다시 살아서 여행을 떠난다, 거짓말이다 거짓말이다.” 하면서 나는 그들을 따랐다...
# 7   바다에까지 나가기도 귀찮아 풀포기에 쓰러진 채 밤을 새웠다. 다음날도 집에 들어가지...
# 8    연숙은 의장에 머리를 기대고 마침내 소리를 내어 운다. 오늘의 이 불행의 원인이 ...
# 9    “글 잘 읽었느냐?” “네에!” “………” 박씨부 인은 말없이 고개만 가볍게 끄덕...
# 10  죽기가 아까운 바는 아니다. 그러나 자기 한 사람이 없어진다 하는 것은 신라의 국가...
# 11   “어떡하랍시요” 급사는 열적은 듯이 혼자 머리를 굽실하면서 또다시 물었다. “간다...
# 12  명수는 얄미운 생각이 났다. “자네가 그렇게 유랑 생활할 생각을 진즉에 하였다면 자...
# 13   “그러기에 등하불명이랍니다. 좌우간 댁부터 수색을 해 보아야 돼요. 어 때요, 명...
# 14  경제생활과 신앙 김교신 나의 오늘날까지의 생애에서 만나 본 사람 중에 가장 간교하고...
# 15   “얼마나 쓰시려우?” “오,십,전,만.”[ADDED] 여인은, 말을 채 마치지를 ...
# 16   경도의 뇌산양이 그리웠다. 연전 서로 만났을 때는 단지 한 개 학자로 서 로 즐겁...
# 17   "그러니까 남녀 평등이란 말 뿐이지, 좀처럼 실현되기는 힘들 꺼예요. 될 수만 있...
# 18  “영애는 그 자리가 좋아서 가나요?” 채영은 영애의 마음을 이 노파를 통해 들어보고...
# 19  “일어나！” 하는 소리는 누가 멀리서 들리는 것 같다. 사슈가는 어안이 벙벙하였다가...
# 20   "앞으로 십 오년만 더 살고 죽으면 저것들이 다 성취하는 것을 보겠지." 김씨 부...
# 21   이것은 그 여인의 뒤에서 짐을 싣고 오다가 목도(目睹)했다는 우차부(牛 車夫)의 ...
# 22   "그렇지만 영훈씨를 늘상 생각하면서 살았으니까, 별반 불행한 삶은 아니 었어요."...
# 23   “두구 보세요 다음 기회는 영락없을 테니. 사람의 운이 한 번은 이로울 날 있겠지...
# 24   어린이는 그림을 좋아한다. 그리고, 또 그리기를 좋아한다.[ADDED] 조금도 기...
# 25   뒤이어 청록파의 지론자인 조지훈은 <예정조화>라는 말을 씀으로써 앞의 인용한 편석...
# 26  4. 극문학 만근(輓近) 각 사립 남녀전문학교를 중심으로 일어나는 신극운동은 실로 ...
# 27  자랑 가만 보면 자랑하려는 마음처럼 무서운 마음은 없는 것 같다. 자기를 자랑하려고...
# 28   그러나 소설이라 하는 것이 문장예술인 이상 마치 회화의 색채와 같은 정 도의 중요...
# 29  SS는 보산을 향하여 예언자와같은 엄숙한 얼굴을 하더니 떡큼직하게하품을 한번하고 나...
# 30   "배라먹 을 녀석! 버르쟁이를 가르쳐야……." 빽 쏘는 소리가 도리어 늦다 할이 ...
# 31   “이놈 버릇 없이……. 흐흥.”[ADDED] 허준이도 담배를 받으면서 점잔을 빼다...
# 32   어느 때인가 상철은 무서운 꿈에서 깨었다. 방안은 캄캄하다.[ADDED] 그것은 ...
# 33  〈노라〉 서 우리 문단의 과거를 회고하여 보라. 우리의 문예는 과거에 우리 생활에 ...
# 34   어머님은 매우 건강한 체질의 소유자였다. 어머님이 제일차의 뇌일혈로 넘어지신 것은...
# 35   낙랑의 북과 나발이 없어진 덕에 고구려는 손쉽게 낙랑을 정복하였다. 말하자면 이번...
# 36  이리하여 수 일이 지났다. 그러는 동안에 이상한 일을 당하였다.[ADDED] 인준에...
# 37  꿈많은 처녀시절 봄은 되었건만 일기는 불순하고 연일 바람이 거세다. 불원(不遠)하여...
# 38  북국점경(北國點景) 능 금(林檎) 능금나무 동산 아름다운 옛 동산, 지금에는 찾을 ...
# 39  사실 나는 근 20년 경성을, 주로 객지의 하숙생활을 하였고, 그러노라 니 늘 겨울...
# 40   "어리기는 열 다섯 살이 어려요?" 평목의 눈이 빛났다.[ADDED] 조신은 한 ...
# 41  음악야화(音樂夜話) 이탈리아 소녀 산뜻한 옷을 맵시 나게 입은 파리의 젊은이들은 가...
# 42   “벌써 반회갑이 아니냐. 너도 내 나이이 돼 봐라.”[ADDED] 나를 쳐다보는 ...
# 43   “그럼 와 그러는 게유? 우리집 이 굶을까 봐 그리시유?”[ADDED] “…….”...
# 44   또 어느날 몬텔뀨는 루이스를 방문하니까 수염이 거친 낯선 남자 하나가 셔츠만 입고...
# 45   × 고금동서에 다시 보기 힘든 명군 세종대왕은, 이러한 불상사를 보신 뒤에 등극을...
# 46  무엇보다 어린 바위가 눈물겹게 불쌍하게 생각이 들었다. 선주는 장사의 눈치를 살피며...
# 47   대처(都市)가 그러한 데 비하여 고향은 차라리 안전하였다. 우선 당장은 각다분하겠...
# 48   남산 밑 풀과 나무에 빛나던 붉은 빛은 점점 걷히고 모색(暮色)이 이물이 물 쳐들...
# 49   원선 이는 숙희 앉은 편으로 뛰어갔다. 서로 손을 잡고 이편으로 뛰어오자, “어서...

# %%
#csv파일로 저장
csv_file_path = '../data/test_data_50.csv'
df.to_csv(csv_file_path, index=False)
