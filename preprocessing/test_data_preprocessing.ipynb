# %%
import pandas as pd

# CSV 파일 경로
file_path = "./data/test_data_chatgptin.csv"

# CSV 파일을 데이터프레임으로 불러오기
df = pd.read_csv(file_path)

# 데이터프레임 확인
print(df.head())
# Out:
#                                            file_path  \
# 0  ./data/validation\REPORT-literature-06726-0672...
# 1  ./data/validation\REPORT-literature-06816-0681...
# 2  ./data/validation\REPORT-literature-06827-0682...
# 3  ./data/validation\REPORT-literature-06921-0692...
# 4  ./data/validation\REPORT-literature-06941-0694...
#
#                                                  new  \
# 0  혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다. 엘리자베트...
# 1   그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 대에 고추...
# 2   두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응. 그래 그...
# 3   그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사 이에는 ...
# 4  “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실한 건축물...
#
#                                                  old  \
# 0           혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다.
# 1   그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 대에 고추...
# 2   두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응. 그래 그...
# 3   그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사 이에는 ...
# 4  “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실한 건축물...
#
#                                             gptinput  \
# 0  문단1. 혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다.\...
# 1  문단1.  그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 ...
# 2  문단1.  두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응....
# 3  문단1.  그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사...
# 4  문단1. “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실...
#
#                                            gptoutput
# 0                  엘리자베트가 혜숙을 원망하며 집으로 돌아가는 내용이 추가됨.
# 1              소녀가 중식의 집에서 점심을 먹으며 모친과 교류하는 내용이 추가됨.
# 2                  필성의 지식에 대해 탄복하며 농민조합에 대한 토론이 추가됨.
# 3               석구와 옥매 사이의 감정적 관계와 그 결과에 대한 성찰이 추가됨.
# 4  영섭이 아내의 격려를 회상하며 자신의 감정과 가족에 대한 생각을 되돌아보는 내용이 ...

# %%
import pandas as pd
import difflib

# 변화를 감지하여 토큰화된 텍스트 생성하는 함수
def detect_changes(old_text, new_text):
    added_parts = []
    for diff in difflib.ndiff(old_text, new_text):
        if diff[0] == '+':
            added_parts.append(diff[2:])
    return old_text + "[ADDED]" + "".join(added_parts) + "[/ADDED]"

# 'text' 열에 변화를 감지한 텍스트 추가
df['text'] = df.apply(lambda row: detect_changes(row['old'], row['new']), axis=1)

# 결과 확인
df
# Out:
#                                            file_path  \
# 0  ./data/validation\REPORT-literature-06726-0672...
# 1  ./data/validation\REPORT-literature-06816-0681...
# 2  ./data/validation\REPORT-literature-06827-0682...
# 3  ./data/validation\REPORT-literature-06921-0692...
# 4  ./data/validation\REPORT-literature-06941-0694...
# 5  ./data/validation\REPORT-literature-06978-0697...
# 6  ./data/validation\REPORT-literature-06988-0698...
# 7  ./data/validation\REPORT-literature-06996-0699...
# 8  ./data/validation\REPORT-literature-07004-0700...
# 9  ./data/validation\REPORT-literature-07023-0702...
#
#                                                  new  \
# 0  혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다. 엘리자베트...
# 1   그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 대에 고추...
# 2   두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응. 그래 그...
# 3   그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사 이에는 ...
# 4  “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실한 건축물...
# 5  “용애는 잘 있는지. 우리 학교는 학생이 많은지.” 잠꼬대 비슷이 봉염이는 지껄이다...
# 6  “너도 먹을 것을 찾고 있지? 그렇거든 파 보아! 나는 고만 손에 힘이 없 어졌어....
# 7  온 몸의 근육이 냉기에 죄어들고 이가 쫏기는 것을 억지로 참아 가면서 한 시간 동안...
# 8   산 산에는 밤 감 잣나무를 심으며 숯 연목을 팔고 빚을 지워 숯을 앗아 팔 고 가...
# 9   그러나, 제 아무리 기쁘고 즐겁더라도 한 가지 근심이 없을 수는 없다. 만 일 우...
#
#                                                  old  \
# 0           혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다.
# 1   그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 대에 고추...
# 2   두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응. 그래 그...
# 3   그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사 이에는 ...
# 4  “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실한 건축물...
# 5                       “용애는 잘 있는지. 우리 학교는 학생이 많은지.”
# 6  “너도 먹을 것을 찾고 있지? 그렇거든 파 보아! 나는 고만 손에 힘이 없 어졌어....
# 7  온 몸의 근육이 냉기에 죄어들고 이가 쫏기는 것을 억지로 참아 가면서 한 시간 동안...
# 8   산 산에는 밤 감 잣나무를 심으며 숯 연목을 팔고 빚을 지워 숯을 앗아 팔 고 가...
# 9   그러나, 제 아무리 기쁘고 즐겁더라도 한 가지 근심이 없을 수는 없다. 만 일 우...
#
#                                             gptinput  \
# 0  문단1. 혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다.\...
# 1  문단1.  그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 ...
# 2  문단1.  두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응....
# 3  문단1.  그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사...
# 4  문단1. “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실...
# 5  문단1. “용애는 잘 있는지. 우리 학교는 학생이 많은지.”\n\n문단2. “용애는...
# 6  문단1. “너도 먹을 것을 찾고 있지? 그렇거든 파 보아! 나는 고만 손에 힘이 없...
# 7  문단1. 온 몸의 근육이 냉기에 죄어들고 이가 쫏기는 것을 억지로 참아 가면서 한 ...
# 8  문단1.  산 산에는 밤 감 잣나무를 심으며 숯 연목을 팔고 빚을 지워 숯을 앗아 ...
# 9  문단1.  그러나, 제 아무리 기쁘고 즐겁더라도 한 가지 근심이 없을 수는 없다. ...
#
#                                            gptoutput  \
# 0                  엘리자베트가 혜숙을 원망하며 집으로 돌아가는 내용이 추가됨.
# 1              소녀가 중식의 집에서 점심을 먹으며 모친과 교류하는 내용이 추가됨.
# 2                  필성의 지식에 대해 탄복하며 농민조합에 대한 토론이 추가됨.
# 3               석구와 옥매 사이의 감정적 관계와 그 결과에 대한 성찰이 추가됨.
# 4  영섭이 아내의 격려를 회상하며 자신의 감정과 가족에 대한 생각을 되돌아보는 내용이 ...
# 5       봉염이의 어머니가 비 오는 밤에 그를 죽이려고 결심하고 있었다는 내용이 추가됨.
# 6                            울막에서 물건을 찾아 파는 장면이 추가됨.
# 7                            주인공의 질병 증상과 관련 대화가 추가됨.
# 8                   동제 부활과 진갑잔치 후의 가족 및 마을의 변화가 추가됨.
# 9                    우식의 불안정한 상황과 그에 대한 옥지의 근심이 추가됨.
#
#                                                 text
# 0  혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다.[ADDED...
# 1   그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 대에 고추...
# 2   두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응. 그래 그...
# 3   그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사 이에는 ...
# 4  “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실한 건축물...
# 5  “용애는 잘 있는지. 우리 학교는 학생이 많은지.”[ADDED] 잠꼬대 비슷이 봉염...
# 6  “너도 먹을 것을 찾고 있지? 그렇거든 파 보아! 나는 고만 손에 힘이 없 어졌어....
# 7  온 몸의 근육이 냉기에 죄어들고 이가 쫏기는 것을 억지로 참아 가면서 한 시간 동안...
# 8   산 산에는 밤 감 잣나무를 심으며 숯 연목을 팔고 빚을 지워 숯을 앗아 팔 고 가...
# 9   그러나, 제 아무리 기쁘고 즐겁더라도 한 가지 근심이 없을 수는 없다. 만 일 우...

# %%
# 'file_path', 'new', 'old', 'gptinput' 열 삭제
df.drop(columns=['file_path', 'new', 'old', 'gptinput'], inplace=True)

# 'gptoutput' 열 이름을 'summary'로 변경
df.rename(columns={'gptoutput': 'summary'}, inplace=True)

df
# Out:
#                                              summary  \
# 0                  엘리자베트가 혜숙을 원망하며 집으로 돌아가는 내용이 추가됨.
# 1              소녀가 중식의 집에서 점심을 먹으며 모친과 교류하는 내용이 추가됨.
# 2                  필성의 지식에 대해 탄복하며 농민조합에 대한 토론이 추가됨.
# 3               석구와 옥매 사이의 감정적 관계와 그 결과에 대한 성찰이 추가됨.
# 4  영섭이 아내의 격려를 회상하며 자신의 감정과 가족에 대한 생각을 되돌아보는 내용이 ...
# 5       봉염이의 어머니가 비 오는 밤에 그를 죽이려고 결심하고 있었다는 내용이 추가됨.
# 6                            울막에서 물건을 찾아 파는 장면이 추가됨.
# 7                            주인공의 질병 증상과 관련 대화가 추가됨.
# 8                   동제 부활과 진갑잔치 후의 가족 및 마을의 변화가 추가됨.
# 9                    우식의 불안정한 상황과 그에 대한 옥지의 근심이 추가됨.
#
#                                                 text
# 0  혜숙이는 엘리자베트의 바람을 이루어 주지를 않았다. 아무 말도 안하였다.[ADDED...
# 1   그래서 두 아가는 의좋게 놀았고 점심때가 되는 줄도 모르는데 뒤꼍 장독 대에 고추...
# 2   두윤이나 정선달은 긴장된 얼굴로 숨만 내쉬면서 이만히 앉아들었다. “응. 그래 그...
# 3   그러나, 지금 옥매로서는 과연 이 지경에까지 이르렀을지. 석구와 옥매 사 이에는 ...
# 4  “이것은 꼭 당선될 것입니다. 내가 생각해도 조선에서는 최신식이면서도 견실한 건축물...
# 5  “용애는 잘 있는지. 우리 학교는 학생이 많은지.”[ADDED] 잠꼬대 비슷이 봉염...
# 6  “너도 먹을 것을 찾고 있지? 그렇거든 파 보아! 나는 고만 손에 힘이 없 어졌어....
# 7  온 몸의 근육이 냉기에 죄어들고 이가 쫏기는 것을 억지로 참아 가면서 한 시간 동안...
# 8   산 산에는 밤 감 잣나무를 심으며 숯 연목을 팔고 빚을 지워 숯을 앗아 팔 고 가...
# 9   그러나, 제 아무리 기쁘고 즐겁더라도 한 가지 근심이 없을 수는 없다. 만 일 우...

# %%
#csv파일로 저장
csv_file_path = './data/test_data.csv'
df.to_csv(csv_file_path, index=False)
