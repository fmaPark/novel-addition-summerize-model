# %%
import pandas as pd

# CSV 파일 경로
file_path = "training_data_chatgptoutput_102.csv"

# CSV 파일을 데이터프레임으로 불러오기
df = pd.read_csv(file_path)

# 데이터프레임 확인
print(df.head())
# Out:
#                                            file_path  \
# 0  ./data/training/REPORT-literature-01895-01895....
# 1  ./data/training/REPORT-literature-08958-08958....
# 2  ./data/training/REPORT-literature-01306-01306....
# 3  ./data/training/REPORT-literature-02927-02927....
# 4  ./data/training/REPORT-literature-01565-01565....
#
#                                                  new  \
# 0   그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1  세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니...
# 2   한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3   "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4  탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다....
#
#                                                  old  \
# 0   그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1   세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니다.
# 2   한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3   "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4     탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다.
#
#                                             gptinput  \
# 0  문단1.  그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그...
# 1  문단1. 세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를...
# 2  문단1.  한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런...
# 3  문단1.  "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주...
# 4  문단1. 탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 ...
#
#                              gptoutput
# 0          생각과 계획, 부부의 감정 및 현실 인식 추가됨.
# 1  가족의 급격한 증가와 염병으로 인한 아이들의 대량 사망 추가됨.
# 2        상동의 무서움과 송장 발견, 하인들의 대화가 추가됨.
# 3    잠자지 못한 주인공이 깨어나 들창 미닫이 열린 것을 발견함.
# 4    김군의 탈출을 비판하고 가족으로 돌아갈 것을 강하게 권고함.

# %%
import pandas as pd
import difflib

# 변화를 감지하여 토큰화된 텍스트 생성하는 함수
def detect_changes(old_text, new_text, sum):
    added_parts = []
    for diff in difflib.ndiff(old_text, new_text):
        if diff[0] == '+':
            added_parts.append(diff[2:])
    return old_text + "[ADDED]" + "".join(added_parts) + "[/ADDED]"

# 'text' 열에 변화를 감지한 텍스트 추가
df['text'] = df.apply(lambda row: detect_changes(row['old'], row['new']), axis=1)

# 결과 확인
df
# Out:
#                                             file_path  \
# 0   ./data/training/REPORT-literature-01895-01895....
# 1   ./data/training/REPORT-literature-08958-08958....
# 2   ./data/training/REPORT-literature-01306-01306....
# 3   ./data/training/REPORT-literature-02927-02927....
# 4   ./data/training/REPORT-literature-01565-01565....
# ..                                                ...
# 95  ./data/training/REPORT-literature-03566-03566....
# 96  ./data/training/REPORT-literature-05538-05538....
# 97  ./data/training/REPORT-literature-10100-10100....
# 98  ./data/training/REPORT-literature-02868-02868....
# 99  ./data/training/REPORT-literature-10216-10216....
#
#                                                   new  \
# 0    그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1   세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니...
# 2    한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3    "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4   탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다....
# ..                                                ...
# 95   사흘 뒤였읍니다. 밤이 깊어서 아씨는 고요히 잠이 들고 서방님은 자리에 누워서 책...
# 96  실낙원 소녀 소녀는 확실히 누구의 사진인가 보다. 언제든지 잠자코 있다. 소녀는 때...
# 97   “당신은 방향 전환을 한 후의 감상이 어떠했던가요?” 라고 마치 나의 가슴을 투시...
# 98  成長[성장] 동중이 공론하여 돈 낼 사람 돈 내고, 양식이나 포백 낼 사람 양식이나...
# 99   영배의 얼굴은 피로의 엷은 베일로 한 꺼풀 싼 것같이 보였다. 입을 한 번 딱 벌...
#
#                                                   old  \
# 0    그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1    세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니다.
# 2    한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3    "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4      탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다.
# ..                                                ...
# 95   사흘 뒤였읍니다. 밤이 깊어서 아씨는 고요히 잠이 들고 서방님은 자리에 누워서 책...
# 96           실낙원 소녀 소녀는 확실히 누구의 사진인가 보다. 언제든지 잠자코 있다.
# 97   “당신은 방향 전환을 한 후의 감상이 어떠했던가요?” 라고 마치 나의 가슴을 투시...
# 98  成長[성장] 동중이 공론하여 돈 낼 사람 돈 내고, 양식이나 포백 낼 사람 양식이나...
# 99   영배의 얼굴은 피로의 엷은 베일로 한 꺼풀 싼 것같이 보였다. 입을 한 번 딱 벌...
#
#                                              gptinput  \
# 0   문단1.  그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그...
# 1   문단1. 세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를...
# 2   문단1.  한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런...
# 3   문단1.  "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주...
# 4   문단1. 탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 ...
# ..                                                ...
# 95  문단1.  사흘 뒤였읍니다. 밤이 깊어서 아씨는 고요히 잠이 들고 서방님은 자리에 ...
# 96  문단1. 실낙원 소녀 소녀는 확실히 누구의 사진인가 보다. 언제든지 잠자코 있다.\...
# 97  문단1.  “당신은 방향 전환을 한 후의 감상이 어떠했던가요?” 라고 마치 나의 가...
# 98  문단1. 成長[성장] 동중이 공론하여 돈 낼 사람 돈 내고, 양식이나 포백 낼 사람...
# 99  문단1.  영배의 얼굴은 피로의 엷은 베일로 한 꺼풀 싼 것같이 보였다. 입을 한 ...
#
#                               gptoutput  \
# 0           생각과 계획, 부부의 감정 및 현실 인식 추가됨.
# 1   가족의 급격한 증가와 염병으로 인한 아이들의 대량 사망 추가됨.
# 2         상동의 무서움과 송장 발견, 하인들의 대화가 추가됨.
# 3     잠자지 못한 주인공이 깨어나 들창 미닫이 열린 것을 발견함.
# 4     김군의 탈출을 비판하고 가족으로 돌아갈 것을 강하게 권고함.
# ..                                  ...
# 95             서방님이 쥐를 잡고 고문하는 장면이 추가됨.
# 96             소녀가 겪는 고통과 환상적인 상황이 추가됨.
# 97    개인적 무력감과 고독, 다시 용기를 얻으려는 감정이 추가됨.
# 98       심봉사의 극심한 피로와 비탄, 손님들의 위로가 추가됨.
# 99            영배의 피로와 가족 간의 작은 불화가 추가됨.
#
#                                                  text
# 0    그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1   세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니...
# 2    한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3    "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4   탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다....
# ..                                                ...
# 95   사흘 뒤였읍니다. 밤이 깊어서 아씨는 고요히 잠이 들고 서방님은 자리에 누워서 책...
# 96  실낙원 소녀 소녀는 확실히 누구의 사진인가 보다. 언제든지 잠자코 있다.[ADDED...
# 97   “당신은 방향 전환을 한 후의 감상이 어떠했던가요?” 라고 마치 나의 가슴을 투시...
# 98  成長[성장] 동중이 공론하여 돈 낼 사람 돈 내고, 양식이나 포백 낼 사람 양식이나...
# 99   영배의 얼굴은 피로의 엷은 베일로 한 꺼풀 싼 것같이 보였다. 입을 한 번 딱 벌...
#
# [100 rows x 6 columns]

# %%
# 'file_path', 'new', 'old', 'gptinput' 열 삭제
df.drop(columns=['file_path', 'new', 'old', 'gptinput'], inplace=True)

# 'gptoutput' 열 이름을 'summary'로 변경
df.rename(columns={'gptoutput': 'summary'}, inplace=True)

df
# Out:
#                                 summary  \
# 0           생각과 계획, 부부의 감정 및 현실 인식 추가됨.
# 1   가족의 급격한 증가와 염병으로 인한 아이들의 대량 사망 추가됨.
# 2         상동의 무서움과 송장 발견, 하인들의 대화가 추가됨.
# 3     잠자지 못한 주인공이 깨어나 들창 미닫이 열린 것을 발견함.
# 4     김군의 탈출을 비판하고 가족으로 돌아갈 것을 강하게 권고함.
# ..                                  ...
# 95             서방님이 쥐를 잡고 고문하는 장면이 추가됨.
# 96             소녀가 겪는 고통과 환상적인 상황이 추가됨.
# 97    개인적 무력감과 고독, 다시 용기를 얻으려는 감정이 추가됨.
# 98       심봉사의 극심한 피로와 비탄, 손님들의 위로가 추가됨.
# 99            영배의 피로와 가족 간의 작은 불화가 추가됨.
#
#                                                  text
# 0    그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1   세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니...
# 2    한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3    "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4   탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다....
# ..                                                ...
# 95   사흘 뒤였읍니다. 밤이 깊어서 아씨는 고요히 잠이 들고 서방님은 자리에 누워서 책...
# 96  실낙원 소녀 소녀는 확실히 누구의 사진인가 보다. 언제든지 잠자코 있다.[ADDED...
# 97   “당신은 방향 전환을 한 후의 감상이 어떠했던가요?” 라고 마치 나의 가슴을 투시...
# 98  成長[성장] 동중이 공론하여 돈 낼 사람 돈 내고, 양식이나 포백 낼 사람 양식이나...
# 99   영배의 얼굴은 피로의 엷은 베일로 한 꺼풀 싼 것같이 보였다. 입을 한 번 딱 벌...
#
# [100 rows x 2 columns]

# %%
#csv파일로 저장
csv_file_path = './training_data.csv'
df.to_csv(csv_file_path, index=False)

# %%
df2 = df.head(10)

df2
# Out:
#                                        summary  \
# 0                  생각과 계획, 부부의 감정 및 현실 인식 추가됨.
# 1          가족의 급격한 증가와 염병으로 인한 아이들의 대량 사망 추가됨.
# 2                상동의 무서움과 송장 발견, 하인들의 대화가 추가됨.
# 3            잠자지 못한 주인공이 깨어나 들창 미닫이 열린 것을 발견함.
# 4            김군의 탈출을 비판하고 가족으로 돌아갈 것을 강하게 권고함.
# 5               며느리와 시아버지의 대화와 집을 팔 결심 과정 추가됨.
# 6   거지아이와 부룩쇠의 대화, 추격, 그리고 부룩쇠의 실망과 탐색 과정 추가됨.
# 7  기생 두옥이의 배경, 그녀가 김 감사한테 수청 드는 일과 관련된 농담 추가됨.
# 8       참혹한 광경 후의 상황, 열차의 지나가는 장면과 주변 상황이 추가됨.
# 9              나귀와 아이들과의 소동, 허생원의 반응과 상황이 추가됨.
#
#                                                 text
# 0   그러나 그들에게는 그대로 C촌이나 예전 고향으로 돌아갈 면목이 없다. 그 런 것을...
# 1  세 살 난 애도 벌써 밥을 먹기 시작하였습니다. 쌀 한 말이 사흘을 가지를 않았읍니...
# 2   한식 경이나 지난 후에 과연 성축 밑으로서 산을 향하여 올라 오면서 두런 거리는 ...
# 3   "요새 세밑이 돼서 도적놈이 다니니 들창 덧문 같은 것도 단단히 걸고 주 무십시오...
# 4  탈출기 1 김군! 수삼 차 편지는 반갑게 받았다. 그러나 한 번도 회답치 못하였다....
# 5   팔패는 마음대로 떨어졌다. 떨어진 팔패와 같이 며느리의 마음은 과연 그 렇게 굳어...
# 6   그러고 거지아이가 척 앉아서 아주 천천히 호떡을 먹고 있는 것이 아주 마음에 지리...
# 7   "관가 노린가 보네." "이 사람 누구 노린 줄도 모르고 있나.[ADDED]" "...
# 8   나는 모골이 송연했다. 보아선 아니 된다.[ADDED] 나는 또 그 무슨 참혹한 ...
# 9  어린아이를 달래듯이 목덜미를 어루만져 주니 나귀는 코를 벌름거리고 입을 투르르거렸다...

# %%
df2.shape
# Out:
# (10, 2)

# %%
#csv파일로 저장
csv_file_path = './validation_data.csv'
df.to_csv(csv_file_path, index=False)
